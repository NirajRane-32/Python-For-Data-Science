# %% [markdown]
# **Laxmi Charitable Trust’s**
#
# Sheth L.U.J College of Arts & Sir M.V. College of Science and Commerce
# Department of Information Technology (Bsc.IT Semester III) *italicized text*
#
# **Python for Data Science Practical**

# %% [markdown]
# # Practical - V

# %% [markdown]
# Name:Niraj Rane
#
# Roll No. :S032
#
# Class :SYIT
#
# Date:12-08-2026

# %% [markdown]
# **a. Write a python code to demonstrate importing pandas libraries and create data frame object**.

# %%
import pandas as pd

data = {
  "name": ["Sally", "Mary", "John"],
  "age": [50, 40, 30],
  "qualified": [True, False, False]
}
df = pd.DataFrame(data)
print(df)

print("NirajRane_S032")
# Out:
#     name  age  qualified
# 0  Sally   50       True
# 1   Mary   40      False
# 2   John   30      False
# NirajRane_S032

# %% [markdown]
# **b.Write a python code to show statistical information on given data set.**

# %%
import statistics

print(statistics.mean([1, 3, 5, 7, 9, 11, 13]))
print(statistics.median([1, 3, 5, 7, 9, 11, 13]))
print(statistics.mode([1, 1, 3, -5, 7, -9, 11]))
print(statistics.stdev([1, 30, 50, 100]))
print(statistics.variance([-11, 5.5, -3.4, 7.1]))

print("NirajRane_S032")
# Out:
# 7
# 7
# 1
# 41.67633221226007
# 70.80333333333333
# NirajRane_S032

# %% [markdown]
# **c.Write a python code to create pandas series from dictionaries.**

# %%
dictionary = {'Rudra': 50, 'Harshal': 10, 'Vedant': 80}
series = pd.Series(dictionary, index=['Vedant', 'Rudra', 'Harshal'])

print(series)

print("NirajRane_S032")
# Out:
# Vedant     80
# Rudra      50
# Harshal    10
# dtype: int64
# NirajRane_S032

# %%
dictionary = {'Alexander': 10, 'Napoleon': 20, 'Marcus': 30}
series = pd.Series(dictionary)

print(series)
# Out:
# Alexander    10
# Napoleon     20
# Marcus       30
# dtype: int64

# %% [markdown]
# **d. Write a python code to demonstrate filter pandas series with Boolean arrays.**

# %%
dict = {'name':["Vedant", "Rudra", "Harshal", "Sumeet"],
        'degree': ["MBA", "BCA", "M.Tech", "MBA"],
        'score':[60, 80, 90, 98]}

df = pd.DataFrame(dict, index = [True, False, True, False])

print(df)
# Out:
#           name  degree  score
# True    Vedant     MBA     60
# False    Rudra     BCA     80
# True   Harshal  M.Tech     90
# False   Sumeet     MBA     98
