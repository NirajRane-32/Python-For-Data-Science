# %% [markdown]
# **Laxmi Charitable Trust’s**
#
# Sheth L.U.J College of Arts & Sir M.V. College of Science and Commerce
# Department of Information Technology (Bsc.IT Semester III) *italicized text*
#
# **Python for Data Science Practical**

# %% [markdown]
# # Practical - VII

# %% [markdown]
# Name:Niraj Rane
#
# Roll No. :S032
#
# Class :SYIT
#
# Date:02-09-2026

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# **A]Write a Python program to create a scatter plot of Age and Height of 5 students.**

# %%
import numpy as np
x = np.array([12, 13, 14, 15, 16])
y= np.array([145, 150, 155, 160, 165])

plt.scatter(x, y)

plt.xlabel("Age")
plt.ylabel("Height (cm)")

plt.title("Scatter Plot of Age and Height")

plt.show()

# %% [markdown]
# **B]Write a Python program to create a bar chart showing marks of 5 students.**

# %%
import numpy as np

x = np.array(["A", "B", "C", "D", "E"])
y = np.array([75, 88, 65, 92, 80])

plt.bar(x, y)

plt.xlabel("Students")
plt.ylabel("Marks")
plt.title("Marks of 5 Students")

plt.show()

# %% [markdown]
# **C]Write a Python program to create a histogram showing the distribution of marks of 10 students.**

# %%
import numpy as np

marks = np.array([45, 56, 67, 72, 80, 85, 90, 62, 74, 55])

plt.hist(marks)

plt.xlabel("Marks")
plt.ylabel("Number of Students")
plt.title("Distribution of Marks of 10 Students")

plt.show()

# %% [markdown]
# **D]Write a Python program to create a pie chart showing the number of students in different courses.**

# %%
import numpy as np

courses = np.array(["Science", "Commerce", "Arts", "Engineering"])
students = np.array([30, 25, 20, 35])

plt.pie(students , labels=courses)

plt.title("Number of Students in Different Courses")

plt.show()

# %% [markdown]
# E]Write a Python program to create a bar chart showing sales of 5 different products.

# %%
products = np.array(["Product A", "Product B", "Product C", "Product D", "Product E"])
sales = np.array([50, 75, 40, 90, 65])

plt.barh(products, sales)

plt.xlabel("Products")
plt.ylabel("Sales")
plt.title("Sales of 5 Different Products")

plt.show()
