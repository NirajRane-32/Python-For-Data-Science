# %% [markdown]
# **Laxmi Charitable Trust’s**
#
# Sheth L.U.J College of Arts & Sir M.V. College of Science and Commerce
# Department of Information Technology (Bsc.IT Semester III) *italicized text*
#
# **Python for Data Science Practical**

# %% [markdown]
# # Practical - VI

# %% [markdown]
# Name:Niraj Rane
#
# Roll No. :S032
#
# Class :SYIT
#
# Date:19-08-2026

# %%
import pandas as pd

# %% [markdown]
# **6a. Write a Python program to import a CSV dataset using Pandas and display the first 5 and last 5 records.**

# %%
df = pd.read_csv("Students.csv")
print(df.head())
# Out:
#    Roll No     Name Department  Marks  Attendance
# 0      101    Rudra     BSc IT     78          85
# 1      102   Sumeet     BSc CS     65          90
# 2      103  Harshal     BSc IT     88          92
# 3      104   Vedant     BSc CS     72          80
# 4      105    Niraj     BSc IT     55          70

# %%
print(df.tail())
# Out:
#    Roll No      Name Department  Marks  Attendance
# 5      106     Viraj         BT     67          67
# 6      107    Deepak      BAMMC     34          34
# 7      108  Jitendra       BCOM     72          54
# 8      109    Ramesh    Bpharma     95          26
# 9      110   Kaushik      BTech     56          64

# %% [markdown]
# **6b. Write a Python program to analyze the dataset by displaying the number of rows and columns, column names, data types, and basic statistical information.**

# %%
print(df.shape) #number of rows and columns
# Out:
# (10, 5)

# %%
print(df.columns)
# Out:
# Index(['Roll No', 'Name', 'Department', 'Marks', 'Attendance'], dtype='object')

# %%
print(df.dtypes)
# Out:
# Roll No        int64
# Name          object
# Department    object
# Marks          int64
# Attendance     int64
# dtype: object

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of    Roll No      Name Department  Marks  Attendance
# 0      101     Rudra     BSc IT     78          85
# 1      102    Sumeet     BSc CS     65          90
# 2      103   Harshal     BSc IT     88          92
# 3      104    Vedant     BSc CS     72          80
# 4      105     Niraj     BSc IT     55          70
# 5      106     Viraj         BT     67          67
# 6      107    Deepak      BAMMC     34          34
# 7      108  Jitendra       BCOM     72          54
# 8      109    Ramesh    Bpharma     95          26
# 9      110   Kaushik      BTech     56          64>

# %% [markdown]
# **6c. Write a Python program to filter records from the dataset using conditions**.

# %%
result = df[df["Attendance"]>=90]
print(result)
# Out:
#    Roll No     Name Department  Marks  Attendance
# 1      102   Sumeet     BSc CS     65          90
# 2      103  Harshal     BSc IT     88          92

# %% [markdown]
# **6d. Write a Python program to sort the dataset based on a selected column and display the top 5 records. For example, sort students by marks or products by price.**

# %%
result = df.sort_values("Marks")
print(result)
# Out:
#    Roll No      Name Department  Marks  Attendance
# 6      107    Deepak      BAMMC     34          34
# 4      105     Niraj     BSc IT     55          70
# 9      110   Kaushik      BTech     56          64
# 1      102    Sumeet     BSc CS     65          90
# 5      106     Viraj         BT     67          67
# 3      104    Vedant     BSc CS     72          80
# 7      108  Jitendra       BCOM     72          54
# 0      101     Rudra     BSc IT     78          85
# 2      103   Harshal     BSc IT     88          92
# 8      109    Ramesh    Bpharma     95          26

# %% [markdown]
# **6e. Write a Python program to perform data analysis on the dataset by finding the maximum, minimum, average, and total values of a numerical column.**

# %%
print("Maximum Marks ",df["Marks"].max())
print("Minimum Marks ",df["Marks"].min())
# Out:
# Maximum Marks  95
# Minimum Marks  34
